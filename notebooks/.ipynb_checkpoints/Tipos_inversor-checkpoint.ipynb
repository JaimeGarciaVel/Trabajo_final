# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv, set_option
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import StandardScaler
 
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score
from sklearn import cluster, covariance, manifold

import matplotlib.ticker as ticker

# %%
inversores = pd.read_csv('../data2/datos_socioeconomicos.csv', index_col = 0 )
inversores
# Out:
#        HHSEX  AGECL  EDCL  MARRIED  KIDS  RACE  OCCAT1  KNOWL  YESFINRISK  \
# 0          2      6     4        2     0     1       1      6           0
# 1          2      6     4        2     0     1       1      6           0
# 2          2      6     4        2     0     1       1      6           0
# 3          2      6     4        2     0     1       1      6           0
# 4          2      6     4        2     0     1       1      6           0
# ...      ...    ...   ...      ...   ...   ...     ...    ...         ...
# 28880      1      3     1        1     0     1       2      7           0
# 28881      1      3     1        1     0     1       2      7           0
# 28882      1      3     1        1     0     1       2      7           0
# 28883      1      3     1        1     0     1       2      7           0
# 28884      1      3     1        1     0     1       2      7           0
#
#        NOFINRISK  NWCAT  INCCAT  Tolerancia_riesgo
# 0              0      5       3           0.926181
# 1              0      5       3           0.919388
# 2              0      5       3           0.921627
# 3              0      5       2           0.944681
# 4              0      5       3           0.925676
# ...          ...    ...     ...                ...
# 28880          1      5       6           0.693498
# 28881          1      5       6           0.697253
# 28882          1      5       6           0.690558
# 28883          1      5       6           0.708311
# 28884          1      5       6           0.719504
#
# [28532 rows x 13 columns]

# %%
inversores.describe()
# Out:
#               HHSEX         AGECL          EDCL       MARRIED          KIDS  \
# count  28532.000000  28532.000000  28532.000000  28532.000000  28532.000000
# mean       1.221926      3.394715      3.086640      1.372634      0.749159
# std        0.415549      1.546389      1.002185      0.483514      1.124878
# min        1.000000      1.000000      1.000000      1.000000      0.000000
# 25%        1.000000      2.000000      2.000000      1.000000      0.000000
# 50%        1.000000      3.000000      3.000000      1.000000      0.000000
# 75%        1.000000      5.000000      4.000000      2.000000      1.000000
# max        2.000000      6.000000      4.000000      2.000000      7.000000
#
#                RACE        OCCAT1         KNOWL    YESFINRISK     NOFINRISK  \
# count  28532.000000  28532.000000  28532.000000  28532.000000  28532.000000
# mean       1.544371      1.794161      7.409961      0.049593      0.311335
# std        1.059825      0.919037      2.151052      0.217107      0.463047
# min        1.000000      1.000000     -1.000000      0.000000      0.000000
# 25%        1.000000      1.000000      6.000000      0.000000      0.000000
# 50%        1.000000      1.000000      8.000000      0.000000      0.000000
# 75%        2.000000      3.000000      9.000000      0.000000      1.000000
# max        5.000000      4.000000     10.000000      1.000000      1.000000
#
#               NWCAT        INCCAT  Tolerancia_riesgo
# count  28532.000000  28532.000000       28532.000000
# mean       3.095962      3.681200           0.414845
# std        1.505394      1.798537           0.432518
# min        1.000000      1.000000          -0.158088
# 25%        2.000000      2.000000           0.000000
# 50%        3.000000      4.000000           0.204529
# 75%        5.000000      6.000000           0.907029
# max        5.000000      6.000000           1.000000

# %%
correlation = inversores.corr()
plt.figure(figsize=(15,15))
plt.title('Correlation Matrix')
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='YlGnBu', linewidths=.3)
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix'}>

# %%
print('Null Values =',inversores.isnull().values.any())
# Out:
# Null Values = False

# %%
import copy
inversores2 = copy.deepcopy(inversores)

# %%
inversores2=inversores2.drop(['Tolerancia_riesgo'], axis=1)
inversores2
# Out:
#        HHSEX  AGECL  EDCL  MARRIED  KIDS  RACE  OCCAT1  KNOWL  YESFINRISK  \
# 0          2      6     4        2     0     1       1      6           0
# 1          2      6     4        2     0     1       1      6           0
# 2          2      6     4        2     0     1       1      6           0
# 3          2      6     4        2     0     1       1      6           0
# 4          2      6     4        2     0     1       1      6           0
# ...      ...    ...   ...      ...   ...   ...     ...    ...         ...
# 28880      1      3     1        1     0     1       2      7           0
# 28881      1      3     1        1     0     1       2      7           0
# 28882      1      3     1        1     0     1       2      7           0
# 28883      1      3     1        1     0     1       2      7           0
# 28884      1      3     1        1     0     1       2      7           0
#
#        NOFINRISK  NWCAT  INCCAT
# 0              0      5       3
# 1              0      5       3
# 2              0      5       3
# 3              0      5       2
# 4              0      5       3
# ...          ...    ...     ...
# 28880          1      5       6
# 28881          1      5       6
# 28882          1      5       6
# 28883          1      5       6
# 28884          1      5       6
#
# [28532 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_rescaled = scaler.fit_transform(inversores2)

data_rescaled
# Out:
# array([[ 1.87243191,  1.68478365,  0.9113849 , ..., -0.67237198,
#          1.26483243, -0.37875903],
#        [ 1.87243191,  1.68478365,  0.9113849 , ..., -0.67237198,
#          1.26483243, -0.37875903],
#        [ 1.87243191,  1.68478365,  0.9113849 , ..., -0.67237198,
#          1.26483243, -0.37875903],
#        ...,
#        [-0.53406481, -0.25525377, -2.08212631, ...,  1.48727198,
#          1.26483243,  1.28929294],
#        [-0.53406481, -0.25525377, -2.08212631, ...,  1.48727198,
#          1.26483243,  1.28929294],
#        [-0.53406481, -0.25525377, -2.08212631, ...,  1.48727198,
#          1.26483243,  1.28929294]])

# %%
import umap

reducer = umap.UMAP(random_state=42)
reducer.fit(data_rescaled.data)
# Out:
# /home/jaimegarcia/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/umap/spectral.py:255: UserWarning: WARNING: spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/jaimegarcia/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/umap/spectral.py:255: UserWarning: WARNING: spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/jaimegarcia/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/umap/spectral.py:255: UserWarning: WARNING: spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# UMAP(dens_frac=0.0, dens_lambda=0.0, random_state=42)

# %%
embedding = reducer.transform(data_rescaled.data)

embedding
# Out:
# array([[ -0.24793369,   2.134551  ],
#        [ -0.24598287,   2.1356642 ],
#        [ -0.24755861,   2.1349108 ],
#        ...,
#        [ -1.1591816 , -12.072851  ],
#        [ -1.1592772 , -12.073259  ],
#        [ -1.159099  , -12.072387  ]], dtype=float32)

# %%
embedding.shape
# Out:
# (28532, 2)

# %%
nclust=7

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=nclust).fit(embedding.data)

kmeans
# Out:
# KMeans(n_clusters=7)

# %%
target_labels=kmeans.predict(embedding.data)
target_labels
# Out:
# array([5, 5, 5, ..., 3, 3, 3], dtype=int32)

# %%
centroids = kmeans.cluster_centers_
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)
scatter = ax.scatter(embedding[:,0],embedding[:,1], c = kmeans.labels_, cmap ="rainbow")
ax.set_title('k-Means results')
plt.colorbar(scatter)

plt.plot(centroids[:,0],centroids[:,1],'sg',markersize=11)

# %%
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=target_labels, s=50, cmap='viridis')
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(kmeans.n_clusters + 1) - 0.5).set_ticks(np.arange(kmeans.n_clusters))

# %%
from sklearn import metrics
print("kmeans", metrics.silhouette_score(embedding, kmeans.labels_, metric='euclidean'))
# Out:
# kmeans 0.3435973

# %%
inversores2['Clusters'] =target_labels
inversores2
# Out:
#        HHSEX  AGECL  EDCL  MARRIED  KIDS  RACE  OCCAT1  KNOWL  YESFINRISK  \
# 0          2      6     4        2     0     1       1      6           0
# 1          2      6     4        2     0     1       1      6           0
# 2          2      6     4        2     0     1       1      6           0
# 3          2      6     4        2     0     1       1      6           0
# 4          2      6     4        2     0     1       1      6           0
# ...      ...    ...   ...      ...   ...   ...     ...    ...         ...
# 28880      1      3     1        1     0     1       2      7           0
# 28881      1      3     1        1     0     1       2      7           0
# 28882      1      3     1        1     0     1       2      7           0
# 28883      1      3     1        1     0     1       2      7           0
# 28884      1      3     1        1     0     1       2      7           0
#
#        NOFINRISK  NWCAT  INCCAT  Clusters
# 0              0      5       3         5
# 1              0      5       3         5
# 2              0      5       3         5
# 3              0      5       2         5
# 4              0      5       3         5
# ...          ...    ...     ...       ...
# 28880          1      5       6         3
# 28881          1      5       6         3
# 28882          1      5       6         3
# 28883          1      5       6         3
# 28884          1      5       6         3
#
# [28532 rows x 13 columns]

# %%
cluster0=inversores2[inversores2.Clusters == 0]
a=cluster0.mean()
a
# Out:
# HHSEX         1.210628
# AGECL         3.267168
# EDCL          3.120844
# MARRIED       1.391167
# KIDS          0.879156
# RACE          1.585052
# OCCAT1        1.762679
# KNOWL         7.455472
# YESFINRISK    0.258190
# NOFINRISK     0.243873
# NWCAT         3.107498
# INCCAT        3.722155
# Clusters      0.000000
# dtype: float64

# %%
cluster1=inversores2[inversores2.Clusters == 1]
b=cluster1.mean()
b
# Out:
# HHSEX         1.216244
# AGECL         3.524419
# EDCL          3.022721
# MARRIED       1.359624
# KIDS          0.790024
# RACE          1.488639
# OCCAT1        1.668582
# KNOWL         7.481066
# YESFINRISK    0.000000
# NOFINRISK     0.320972
# NWCAT         3.136328
# INCCAT        3.734134
# Clusters      1.000000
# dtype: float64

# %%
cluster2=inversores2[inversores2.Clusters == 2]
c=cluster2.mean()
c
# Out:
# HHSEX         1.185562
# AGECL         3.458431
# EDCL          3.280688
# MARRIED       1.311181
# KIDS          0.641126
# RACE          1.579098
# OCCAT1        1.909825
# KNOWL         7.709930
# YESFINRISK    0.000000
# NOFINRISK     0.284076
# NWCAT         3.281991
# INCCAT        3.923899
# Clusters      2.000000
# dtype: float64

# %%
cluster3=inversores2[inversores2.Clusters == 3]
d=cluster3.mean()
d
# Out:
# HHSEX         1.219389
# AGECL         3.519061
# EDCL          3.152234
# MARRIED       1.363797
# KIDS          0.665236
# RACE          1.359253
# OCCAT1        1.751325
# KNOWL         7.327695
# YESFINRISK    0.000000
# NOFINRISK     0.306993
# NWCAT         3.202727
# INCCAT        3.855844
# Clusters      3.000000
# dtype: float64

# %%
cluster4=inversores2[inversores2.Clusters == 4]
e=cluster4.mean()
e
# Out:
# HHSEX         1.194894
# AGECL         3.542685
# EDCL          3.224540
# MARRIED       1.339281
# KIDS          0.632995
# RACE          1.530058
# OCCAT1        1.892671
# KNOWL         7.607192
# YESFINRISK    0.000000
# NOFINRISK     0.326105
# NWCAT         3.320340
# INCCAT        3.809223
# Clusters      4.000000
# dtype: float64

# %%
cluster5=inversores2[inversores2.Clusters == 5]
f=cluster5.mean()
f
# Out:
# HHSEX         1.281085
# AGECL         3.120761
# EDCL          2.814619
# MARRIED       1.434627
# KIDS          0.819141
# RACE          1.675961
# OCCAT1        1.733610
# KNOWL         6.947249
# YESFINRISK    0.001884
# NOFINRISK     0.369442
# NWCAT         2.545026
# INCCAT        3.069894
# Clusters      5.000000
# dtype: float64

# %%
cluster6=inversores2[inversores2.Clusters == 6]
g=cluster6.mean()
g
# Out:
# HHSEX         1.222541
# AGECL         3.448735
# EDCL          3.097313
# MARRIED       1.382207
# KIDS          0.776937
# RACE          1.544221
# OCCAT1        1.872163
# KNOWL         7.528046
# YESFINRISK    0.088964
# NOFINRISK     0.311505
# NWCAT         3.296374
# INCCAT        3.885729
# Clusters      6.000000
# dtype: float64

# %%
cluster_output=pd.concat([a,b,c,d,e,f,g],axis=1)
cluster_output
# Out:
#                    0         1         2         3         4         5  \
# HHSEX       1.210628  1.216244  1.185562  1.219389  1.194894  1.281085
# AGECL       3.267168  3.524419  3.458431  3.519061  3.542685  3.120761
# EDCL        3.120844  3.022721  3.280688  3.152234  3.224540  2.814619
# MARRIED     1.391167  1.359624  1.311181  1.363797  1.339281  1.434627
# KIDS        0.879156  0.790024  0.641126  0.665236  0.632995  0.819141
# RACE        1.585052  1.488639  1.579098  1.359253  1.530058  1.675961
# OCCAT1      1.762679  1.668582  1.909825  1.751325  1.892671  1.733610
# KNOWL       7.455472  7.481066  7.709930  7.327695  7.607192  6.947249
# YESFINRISK  0.258190  0.000000  0.000000  0.000000  0.000000  0.001884
# NOFINRISK   0.243873  0.320972  0.284076  0.306993  0.326105  0.369442
# NWCAT       3.107498  3.136328  3.281991  3.202727  3.320340  2.545026
# INCCAT      3.722155  3.734134  3.923899  3.855844  3.809223  3.069894
# Clusters    0.000000  1.000000  2.000000  3.000000  4.000000  5.000000
#
#                    6
# HHSEX       1.222541
# AGECL       3.448735
# EDCL        3.097313
# MARRIED     1.382207
# KIDS        0.776937
# RACE        1.544221
# OCCAT1      1.872163
# KNOWL       7.528046
# YESFINRISK  0.088964
# NOFINRISK   0.311505
# NWCAT       3.296374
# INCCAT      3.885729
# Clusters    6.000000

# %%
cluster_output=cluster_output.drop(['Clusters'],axis=0)
cluster_output
# Out:
#                    0         1         2         3         4         5  \
# HHSEX       1.210628  1.216244  1.185562  1.219389  1.194894  1.281085
# AGECL       3.267168  3.524419  3.458431  3.519061  3.542685  3.120761
# EDCL        3.120844  3.022721  3.280688  3.152234  3.224540  2.814619
# MARRIED     1.391167  1.359624  1.311181  1.363797  1.339281  1.434627
# KIDS        0.879156  0.790024  0.641126  0.665236  0.632995  0.819141
# RACE        1.585052  1.488639  1.579098  1.359253  1.530058  1.675961
# OCCAT1      1.762679  1.668582  1.909825  1.751325  1.892671  1.733610
# KNOWL       7.455472  7.481066  7.709930  7.327695  7.607192  6.947249
# YESFINRISK  0.258190  0.000000  0.000000  0.000000  0.000000  0.001884
# NOFINRISK   0.243873  0.320972  0.284076  0.306993  0.326105  0.369442
# NWCAT       3.107498  3.136328  3.281991  3.202727  3.320340  2.545026
# INCCAT      3.722155  3.734134  3.923899  3.855844  3.809223  3.069894
#
#                    6
# HHSEX       1.222541
# AGECL       3.448735
# EDCL        3.097313
# MARRIED     1.382207
# KIDS        0.776937
# RACE        1.544221
# OCCAT1      1.872163
# KNOWL       7.528046
# YESFINRISK  0.088964
# NOFINRISK   0.311505
# NWCAT       3.296374
# INCCAT      3.885729

# %%
cluster_output=cluster_output.T
cluster_output
# Out:
#       HHSEX     AGECL      EDCL   MARRIED      KIDS      RACE    OCCAT1  \
# 0  1.210628  3.267168  3.120844  1.391167  0.879156  1.585052  1.762679
# 1  1.216244  3.524419  3.022721  1.359624  0.790024  1.488639  1.668582
# 2  1.185562  3.458431  3.280688  1.311181  0.641126  1.579098  1.909825
# 3  1.219389  3.519061  3.152234  1.363797  0.665236  1.359253  1.751325
# 4  1.194894  3.542685  3.224540  1.339281  0.632995  1.530058  1.892671
# 5  1.281085  3.120761  2.814619  1.434627  0.819141  1.675961  1.733610
# 6  1.222541  3.448735  3.097313  1.382207  0.776937  1.544221  1.872163
#
#       KNOWL  YESFINRISK  NOFINRISK     NWCAT    INCCAT
# 0  7.455472    0.258190   0.243873  3.107498  3.722155
# 1  7.481066    0.000000   0.320972  3.136328  3.734134
# 2  7.709930    0.000000   0.284076  3.281991  3.923899
# 3  7.327695    0.000000   0.306993  3.202727  3.855844
# 4  7.607192    0.000000   0.326105  3.320340  3.809223
# 5  6.947249    0.001884   0.369442  2.545026  3.069894
# 6  7.528046    0.088964   0.311505  3.296374  3.885729

# %%
cluster_output[['HHSEX','AGECL','MARRIED','KIDS','EDCL','OCCAT1','RACE','KNOWL','YESFINRISK','NOFINRISK','NWCAT','INCCAT']].plot.bar(rot=0, figsize=(25,10));

# %%
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(kmeans, k=(2,24))

visualizer.fit(embedding)
visualizer.show();

# %%
from sklearn.cluster import DBSCAN

dbscan_c = DBSCAN(eps=1.5,min_samples=25).fit(embedding)

dbscan_c
# Out:
# DBSCAN(eps=1.5, min_samples=25)

# %%
core_samples_mask = np.zeros_like(dbscan_c.labels_, dtype=bool)
core_samples_mask[dbscan_c.core_sample_indices_] = True
labels = dbscan_c.labels_

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 96

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=dbscan_c.labels_, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(len(np.unique(dbscan_c.labels_)) + 1) - 0.5).set_ticks(np.arange(len(np.unique(dbscan_c.labels_))))
plt.title('DBSCAN over the Digits dataset', fontsize=24);
