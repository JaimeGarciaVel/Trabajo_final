# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# %%
df = pd.read_excel('../data/dataframe redes sociales.xlsx')
df.head(10)
# Out:
#   FotoFB NombreFB  AmigosFB  PublicacionesFB InformaciónFB FotoTW NombreTW  \
# 0     NO       SI        95              400            SI      0        0
# 1     SI       SI       241              498            SI      0        0
# 2     NO       SI        96                0            NO     NO       SI
# 3     SI       SI        33               20            NO      0        0
# 4     SI       SI       100               45            SI     NO       SI
# 5     SI       SI       222              130            SI     SI       SI
# 6     SI       SI       126                0            NO      0        0
# 7     SI       SI        61               52            SI      0        0
# 8      0        0         0                0             0      0        0
# 9      0        0         0                0             0      0        0
#
#    SeguidoresTW  SeguidosTW  PublicacionesTW FotoINST NombreINST  \
# 0             0           0                0       NO         SI
# 1             0           0                0        0          0
# 2            34          88                0       NO         SI
# 3             0           0                0        0          0
# 4             2           6                0       SI         SI
# 5             1          39                0       SI         SI
# 6             0           0                0       SI         NO
# 7             0           0                0       SI         SI
# 8             0           0                0        0          0
# 9             0           0                0        0          0
#
#    SeguidoresINST  SeguidosINST PerfilINST  PublicacionesINST Perfil_inversor
# 0              39           104    PRIVADO                  0        moderado
# 1               0             0          0                  0        agresivo
# 2              95            39    PÚBLICO                  0     conservador
# 3               0             0          0                  0     conservador
# 4              60           578    PRIVADO                  0     conservador
# 5             103           113    PRIVADO                 27     conservador
# 6             114           127    PRIVADO                  5        moderado
# 7              54           123    PRIVADO                  5     conservador
# 8               0             0          0                  0        moderado
# 9               0             0          0                  0        moderado

# %%
df.FotoFB = df.FotoFB.replace({"NO": 1, "SI":2})

# %%
df.NombreFB = df.NombreFB.replace({"NO": 1, "SI":2})

# %%
df.InformaciónFB = df.InformaciónFB.replace({"NO": 1, "SI":2})

# %%
df.FotoTW = df.FotoTW.replace({"NO": 1, "SI":2})

# %%
df.NombreTW = df.NombreTW.replace({"NO": 1, "SI":2})

# %%
df.FotoINST = df.FotoINST.replace({"NO": 1, "SI":2})

# %%
df.NombreINST = df.NombreINST.replace({"NO": 1, "SI":2})

# %%
df.PerfilINST = df.PerfilINST.replace({"PRIVADO": 1, "PÚBLICO":2})

# %%
df.Perfil_inversor = df.Perfil_inversor.replace({"conservador": 0, "moderado":1, "agresivo":2})

# %%
df
# Out:
#     FotoFB  NombreFB  AmigosFB  PublicacionesFB  InformaciónFB  FotoTW  \
# 0        1         2        95              400              2       0
# 1        2         2       241              498              2       0
# 2        1         2        96                0              1       1
# 3        2         2        33               20              1       0
# 4        2         2       100               45              2       1
# 5        2         2       222              130              2       2
# 6        2         2       126                0              1       0
# 7        2         2        61               52              2       0
# 8        0         0         0                0              0       0
# 9        0         0         0                0              0       0
# 10       0         0         0                0              0       0
# 11       2         2       155               38              1       2
# 12       1         2       206               52              2       0
# 13       1         2       130               40              1       0
# 14       2         2        60               20              1       0
# 15       1         1        62                5              1       0
# 16       2         2       207                0              1       2
# 17       1         2        36               23              2       1
# 18       2         2       382                4              2       0
# 19       1         2        12                0              2       0
# 20       2         2         6                0              2       2
# 21       0         0         0                0              0       2
# 22       0         0         0                0              0       0
# 23       0         0         0                0              0       2
# 24       0         0         0                0              0       0
# 25       0         0         0                0              0       1
# 26       2         2        69                0              2       0
# 27       0         0         0                0              0       0
# 25                0
# 26                0
# 27                0
# 28                0
# 29                0
# 30                0
# 31                1
# 32                1
# 33                2
# 34                1
# 35                2
# 36                1
# 37                2

# %%
correlation = df.corr()
plt.figure(figsize=(15,15))
plt.title('Correlation Matrix')
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='YlGnBu', linewidths=.3)
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix'}>

# %%
FEATS = ['FotoFB', 'NombreFB', 'AmigosFB', 'PublicacionesFB', 'InformaciónFB', 'FotoTW', 'NombreTW', 'SeguidoresTW', 'SeguidosTW', 'PublicacionesTW', 'FotoINST', 'NombreINST', 'SeguidoresINST', 'SeguidosINST', 'PerfilINST', 'PublicacionesINST']
TARGET = 'Perfil_inversor'

# %%
numeric_transformer = \
Pipeline(steps=[('imputer', SimpleImputer(strategy='median')), 
                ('scaler', StandardScaler())])

# %%
preprocessor = \
ColumnTransformer(transformers=[('num', numeric_transformer, FEATS)])

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (28, 17)
# (10, 17)

# %%
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

model= Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', RandomForestRegressor())])

# %%
model.fit(df_train[FEATS], df_train[TARGET]);

# %%
y_test = model.predict(df_test[FEATS])
y_train = model.predict(df_train[FEATS])

# %%
from sklearn.metrics import mean_squared_error
print(f"test error: {mean_squared_error(y_pred=y_test, y_true=df_test[TARGET], squared=False)}")
print(f"train error: {mean_squared_error(y_pred=y_train, y_true=df_train[TARGET], squared=False)}")
# Out:
# test error: 0.8820792212764733
# train error: 0.34510051835966404

# %%
import eli5
eli5.show_weights(model.named_steps['regressor'], feature_names=FEATS)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1661
#
#                     &plusmn; 0.3441
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SeguidosINST
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1608
#
#                     &plusmn; 0.3547
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AmigosFB
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1363
#
#                     &plusmn; 0.3118
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SeguidoresINST
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1040
#
#                     &plusmn; 0.3093
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PublicacionesFB
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0795
#
#                     &plusmn; 0.2609
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 InformaciónFB
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0649
#
#                     &plusmn; 0.1624
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PublicacionesINST
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0628
#
#                     &plusmn; 0.2327
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NombreTW
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0447
#
#                     &plusmn; 0.2070
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FotoTW
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0444
#
#                     &plusmn; 0.1405
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SeguidosTW
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0373
#
#                     &plusmn; 0.1850
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SeguidoresTW
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0236
#
#                     &plusmn; 0.1177
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FotoINST
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0206
#
#                     &plusmn; 0.0877
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FotoFB
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0202
#
#                     &plusmn; 0.1092
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PublicacionesTW
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0201
#
#                     &plusmn; 0.0901
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PerfilINST
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0079
#
#                     &plusmn; 0.0811
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NombreFB
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0069
#
#                     &plusmn; 0.0429
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NombreINST
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
from pickle import dump
from pickle import load

filename = 'Modelo_redes_sociales.pkl'
dump(model, open(filename, 'wb'))

# %%
filename = 'Modelo_redes_sociales.pkl'
loaded_model = load(open(filename, 'rb'))

# %%
lst = [[1, 1, 500, 300, 1, 0, 0, 500, 550, 35, 1, 1, 500, 535, 2, 15]]
X = pd.DataFrame(lst, columns=['FotoFB', 'NombreFB', 'AmigosFB', 'PublicacionesFB', 'InformaciónFB', 'FotoTW', 'NombreTW', 'SeguidoresTW', 'SeguidosTW', 
                               'PublicacionesTW', 'FotoINST', 'NombreINST', 'SeguidoresINST', 'SeguidosINST', 'PerfilINST', 'PublicacionesINST'])
predictions = loaded_model.predict(X)

# %%
predictions
# Out:
# array([1.27])
