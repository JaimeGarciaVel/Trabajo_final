# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv, set_option
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import StandardScaler
 
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_mutual_info_score
from sklearn import cluster, covariance, manifold

import matplotlib.ticker as ticker

# %%
stock = pd.read_csv('../data2/SP500Data.csv',index_col=0)
stock
# Out:
#                   ABT        ABBV        ABMD         ACN       ATVI  \
# Date
# 2018-01-02  58.790001   98.410004  192.490005  153.839996  64.309998
# 2018-01-03  58.919998   99.949997  195.820007  154.550003  65.309998
# 2018-01-04  58.820000   99.379997  199.250000  156.380005  64.660004
# 2018-01-05  58.990002  101.110001  202.320007  157.669998  66.370003
# 2018-01-08  58.820000   99.489998  207.800003  158.929993  66.629997
# ...               ...         ...         ...         ...        ...
# 2019-10-07  81.040001   74.330002  164.429993  186.809998  55.410000
# 2019-10-08  78.510002   73.529999  159.490005  182.199997  54.130001
# 2019-10-09  79.500000   73.300003  159.309998  184.339996  53.430000
# 2019-10-10  80.139999   74.449997  162.339996  183.830002  53.689999
# 2019-10-11  79.629997   73.629997  169.639999  184.970001  54.820000
#
#                   ADBE        AMD         AAP    AES         AMG  ...  \
# Date                                                              ...
# 2018-01-02  177.699997  10.980000  106.089996  10.88  203.039993  ...
# 2018-01-03  181.039993  11.550000  107.050003  10.87  202.119995  ...
# 2018-01-04  183.220001  12.120000  111.000000  10.83  198.539993  ...
# 2018-01-05  185.339996  11.880000  112.180000  10.87  199.470001  ...
# 2018-01-08  185.039993  12.280000  111.389999  10.87  200.529999  ...
# ...                ...        ...         ...    ...         ...  ...
# 2019-10-07  276.899994  28.930000  158.270004  15.85   74.830002  ...
# 2019-10-08  270.829987  28.230000  154.330002  15.51   71.800003  ...
# 2019-10-09  274.269989  28.459999  154.410004  15.54   72.250000  ...
# 2019-10-10  274.980011  28.379999  155.949997  15.82   73.059998  ...
# 2019-10-11  278.290009  29.750000  158.559998  16.01   75.970001  ...
#
#                   WLTW        WYNN        XEL        XRX       XLNX  \
# Date
# 2018-01-02  146.990005  164.300003  47.810001  29.370001  67.879997
# 2018-01-03  149.740005  162.520004  47.490002  29.330000  69.239998
# 2018-01-04  151.259995  163.399994  47.119999  29.690001  70.489998
# 2018-01-05  152.229996  164.490005  46.790001  29.910000  74.150002
# 2018-01-08  151.410004  162.300003  47.139999  30.260000  74.639999
# ...                ...         ...        ...        ...        ...
# 2019-10-07  187.589996  107.019997  64.279999  29.830000  92.629997
# 2019-10-08  184.360001  102.570000  63.590000  28.309999  89.269997
# 2019-10-09  186.199997  104.419998  63.919998  28.760000  90.480003
# 2019-10-10  187.690002  106.059998  63.950001  28.820000  92.809998
# 2019-10-11  188.100006  112.779999  63.330002  29.410000  96.220001
#
#                   XYL         YUM         ZBH       ZION         ZTS
# Date
# 2018-01-02  68.070000   81.599998  124.059998  50.700001   71.769997
# 2018-01-03  68.900002   81.529999  124.919998  50.639999   72.099998
# 2018-01-04  69.360001   82.360001  124.739998  50.849998   72.529999
# 2018-01-05  69.230003   82.839996  125.980003  50.869999   73.360001
# 2018-01-08  69.480003   82.980003  126.220001  50.619999   74.239998
# ...               ...         ...         ...        ...         ...
# 2019-10-07  75.570000  113.690002  134.500000  43.439999  126.070000
# 2019-10-08  73.430000  112.589996  131.220001  42.209999  125.379997
# 2019-10-09  74.570000  113.330002  133.419998  42.419998  126.430000
# 2019-10-10  75.430000  114.330002  134.070007  43.209999  127.410004
# 2019-10-11  77.629997  114.449997  136.440002  44.090000  128.470001
#
# [448 rows x 502 columns]

# %%
stock.describe()
# Out:
#               ABT        ABBV        ABMD         ACN        ATVI        ADBE  \
# count  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000
# mean    70.934196   88.078013  307.303839  167.473750   59.630804  252.270603
# std      9.015754   13.480891   71.989893   14.635497   13.119012   29.001055
# min     56.270000   62.980000  159.309998  133.669998   40.110001  177.699997
# 25%     62.620001   78.657503  260.557487  157.280006   47.037500  235.377495
# 50%     70.014999   88.524998  301.940002  162.880005   55.269999  254.684998
# 75%     78.620003   96.667498  368.095001  178.337502   71.565002  272.989990
# max     88.739998  123.209999  449.750000  201.119995   83.389999  311.269989
#
#               AMD         AAP         AES         AMG  ...        WLTW  \
# count  448.000000  448.000000  448.000000  448.000000  ...  448.000000
# mean    21.804754  147.501428   14.534888  128.423750  ...  165.139486
# std      7.425020   21.095302    2.266254   38.573308  ...   17.383970
# min      9.530000  103.760002   10.060000   71.800003  ...  134.839996
# 25%     15.147500  133.307499   12.847500   94.059998  ...  151.705002
# 50%     21.885000  154.949997   14.830000  113.389999  ...  158.809998
# 75%     28.437500  163.614998   16.355000  158.855000  ...  178.064999
# max     34.389999  184.720001   18.410000  215.759995  ...  199.360001
#
#              WYNN         XEL         XRX        XLNX         XYL         YUM  \
# count  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000
# mean   139.475335   51.671027   29.151071   90.774487   74.549040   93.492455
# std     29.251895    6.650626    3.450413   21.081242    4.926937   11.958700
# min     92.010002   42.130001   18.920000   62.820000   61.380001   76.300003
# 25%    114.085001   45.689999   27.139999   71.664999   70.547503   83.507502
# 50%    132.974998   49.370001   29.075000   85.195000   75.165001   89.930000
# 75%    164.927498   56.715001   31.455000  109.367500   78.359999  101.462500
# max    201.509995   65.820000   36.480000  139.720001   84.410004  119.209999
#
#               ZBH        ZION         ZTS
# count  448.000000  448.000000  448.000000
# mean   120.406161   49.230245   94.787232
# std      9.199975    4.820335   14.395919
# min     97.230003   38.509998   71.510002
# 25%    114.030001   45.107500   84.557499
# 50%    120.645000   49.184999   90.090000
# 75%    125.850002   53.214999  101.970001
# max    142.610001   58.540001  128.470001
#
# [8 rows x 502 columns]

# %%
stock=stock.fillna(method='bfill')

# %%
print('Null Values =',stock.isnull().values.any())
# Out:
# Null Values = False

# %%
#Calculamos la media de retorno y volatilidad de cada acción en el periodo de un año, tener en cuenta que la bolsa está abierta 251 días (365-2*52-10)
returns = stock.pct_change().mean() * 251
data = pd.DataFrame(returns)
data.columns = ['Retorno']
data['Volatilidad'] = stock.pct_change().std() * np.sqrt(251)
data
# Out:
#        Retorno  Volatilidad
# ABT   0.194343     0.218650
# ABBV -0.108585     0.326830
# ABMD  0.045044     0.471401
# ACN   0.125914     0.211479
# ATVI -0.017491     0.377451
# ...        ...          ...
# XYL   0.103482     0.244002
# YUM   0.205373     0.174906
# ZBH   0.080085     0.231859
# ZION -0.045435     0.256582
# ZTS   0.352338     0.225339
#
# [502 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(data)
X = pd.DataFrame(scaler.fit_transform(data),columns = data.columns, index = data.index)

X
# Out:
#        Retorno  Volatilidad
# ABT   0.800950    -0.690332
# ABBV -0.924132     0.802632
# ABMD -0.049262     2.797809
# ACN   0.411267    -0.789286
# ATVI -0.405378     1.501240
# ...        ...          ...
# XYL   0.283527    -0.340456
# YUM   0.863764    -1.294018
# ZBH   0.150286    -0.508037
# ZION -0.564515    -0.166845
# ZTS   1.700686    -0.598018
#
# [502 rows x 2 columns]

# %%
distorsions = []
max_loop=20
for k in range(2, max_loop):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    distorsions.append(kmeans.inertia_)
fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, max_loop), distorsions)
plt.xticks([i for i in range(2, max_loop)], rotation=75)
plt.grid(True)

# %%
nclust=6

# %%
k_means = cluster.KMeans(n_clusters=nclust)
k_means.fit(X)
# Out:
# KMeans(n_clusters=6)

# %%
target_labels = k_means.predict(X)
target_labels
# Out:
# array([5, 4, 3, 5, 4, 2, 3, 2, 2, 1, 5, 2, 5, 2, 4, 1, 5, 4, 3, 5, 4, 1,
#        5, 5, 2, 2, 0, 2, 0, 5, 1, 5, 5, 0, 5, 5, 0, 4, 5, 5, 5, 2, 2, 0,
#        5, 0, 1, 5, 2, 4, 4, 5, 4, 3, 5, 5, 5, 0, 3, 5, 2, 5, 0, 1, 2, 0,
#        0, 5, 5, 5, 4, 1, 0, 4, 2, 0, 4, 5, 2, 0, 4, 2, 0, 1, 2, 4, 0, 1,
#        4, 2, 0, 4, 0, 5, 0, 2, 2, 4, 4, 5, 1, 0, 4, 0, 2, 0, 3, 5, 2, 0,
#        1, 5, 2, 2, 0, 0, 5, 0, 5, 5, 5, 0, 0, 5, 0, 4, 1, 4, 5, 0, 2, 2,
#        4, 0, 5, 1, 5, 2, 0, 0, 4, 5, 5, 4, 4, 0, 4, 1, 1, 5, 0, 4, 4, 1,
#        2, 4, 5, 5, 0, 5, 5, 5, 1, 1, 4, 0, 0, 4, 5, 4, 2, 4, 0, 5, 1, 5,
#        5, 5, 5, 2, 5, 5, 5, 5, 2, 5, 5, 0, 0, 4, 2, 5, 1, 5, 0, 5, 5, 2,
#        2, 2, 4, 0, 0, 2, 0, 0, 0, 0, 0, 1, 1, 2, 2, 0, 1, 0, 4, 5, 0, 5,
#        2, 0, 2, 1, 1, 0, 5, 2, 2, 5, 1, 5, 5, 3, 4, 5, 4, 5, 5, 5, 5, 0,
#        4, 0, 0, 0, 5, 2, 5, 0, 3, 5, 4, 5, 0, 4, 0, 0, 0, 2, 2, 1, 1, 2,
#        0, 5, 2, 0, 0, 0, 5, 5, 0, 2, 0, 0, 2, 5, 5, 5, 2, 4, 1, 4, 1, 2,
#        0, 3, 2, 4, 0, 5, 4, 5, 0, 5, 0, 5, 5, 2, 0, 0, 1, 1, 1, 4, 2, 0,
#        5, 2, 0, 2, 2, 4, 5, 0, 5, 5, 0, 0, 4, 4, 3, 2, 5, 1, 0, 5, 4, 2,
#        0, 4, 2, 2, 1, 5, 1, 4, 3, 1, 0, 0, 0, 5, 1, 2, 5, 1, 1, 2, 0, 2,
#        0, 2, 0, 3, 4, 2, 0, 0, 5, 5, 0, 0, 0, 5, 2, 0, 0, 5, 0, 1, 5, 0,
#        0, 5, 4, 0, 0, 5, 0, 5, 2, 5, 0, 5, 5, 4, 1, 3, 0, 4, 5, 4, 0, 5,
#        5, 5, 4, 0, 5, 2, 4, 0, 5, 5, 2, 4, 2, 5, 1, 3, 0, 5, 5, 0, 4, 0,
#        0, 5, 0, 2, 4, 2, 0, 5, 0, 4, 3, 0, 2, 5, 5, 0, 3, 1, 2, 0, 4, 2,
#        2, 0, 2, 4, 3, 2, 2, 2, 5, 3, 0, 5, 3, 5, 3, 3, 2, 2, 0, 0, 1, 5,
#        2, 1, 2, 4, 0, 5, 2, 5, 5, 4, 4, 2, 0, 4, 4, 5, 0, 5, 5, 0, 5, 2,
#        0, 5, 1, 5, 1, 0, 4, 0, 5, 1, 5, 4, 3, 5, 5, 5, 0, 2], dtype=int32)

# %%
centroids = k_means.cluster_centers_
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)
scatter = ax.scatter(X.iloc[:,0],X.iloc[:,1], c = k_means.labels_, cmap ="rainbow", label = X.index)
ax.set_title('k-Means results')
ax.set_xlabel('Mean Return')
ax.set_ylabel('Volatility')
plt.colorbar(scatter)

plt.plot(centroids[:,0],centroids[:,1],'sg',markersize=11)

# %%
clustered_series = pd.Series(index=X.index, data=k_means.labels_.flatten())
clustered_series_all = pd.Series(index=X.index, data=k_means.labels_.flatten())
clustered_series = clustered_series[clustered_series != -1]

plt.figure(figsize=(12,7))
plt.barh(
    range(len(clustered_series.value_counts())),
    clustered_series.value_counts()
)
plt.xlabel('Número de stocks en cluster')
plt.ylabel('Número de cluster')
plt.show()

# %%
from sklearn import metrics
print("km", metrics.silhouette_score(X, k_means.labels_, metric='euclidean'))
# Out:
# km 0.3475880656030737

# %%
data['Clusters'] =target_labels
data
# Out:
#        Retorno  Volatilidad  Clusters
# ABT   0.194343     0.218650         5
# ABBV -0.108585     0.326830         4
# ABMD  0.045044     0.471401         3
# ACN   0.125914     0.211479         5
# ATVI -0.017491     0.377451         4
# ...        ...          ...       ...
# XYL   0.103482     0.244002         5
# YUM   0.205373     0.174906         5
# ZBH   0.080085     0.231859         5
# ZION -0.045435     0.256582         0
# ZTS   0.352338     0.225339         2
#
# [502 rows x 3 columns]

# %%
cluster0=data[data.Clusters == 0]
a=cluster0.mean()
a
# Out:
# Retorno       -0.047236
# Volatilidad    0.249465
# Clusters       0.000000
# dtype: float64

# %%
cluster1=data[data.Clusters == 1]
b=cluster1.mean()
b
# Out:
# Retorno       -0.276846
# Volatilidad    0.377224
# Clusters       1.000000
# dtype: float64

# %%
cluster2=data[data.Clusters == 2]
c=cluster2.mean()
c
# Out:
# Retorno        0.242937
# Volatilidad    0.265601
# Clusters       2.000000
# dtype: float64

# %%
cluster3=data[data.Clusters == 3]
d=cluster3.mean()
d
# Out:
# Retorno        0.225708
# Volatilidad    0.429276
# Clusters       3.000000
# dtype: float64

# %%
cluster4=data[data.Clusters == 4]
e=cluster4.mean()
e
# Out:
# Retorno        0.007011
# Volatilidad    0.323167
# Clusters       4.000000
# dtype: float64

# %%
cluster5=data[data.Clusters == 5]
f=cluster5.mean()
f
# Out:
# Retorno        0.137145
# Volatilidad    0.197936
# Clusters       5.000000
# dtype: float64

# %%
cluster_output=pd.concat([a,b,c,d,e,f],axis=1)
cluster_output
# Out:
#                     0         1         2         3         4         5
# Retorno     -0.047236 -0.276846  0.242937  0.225708  0.007011  0.137145
# Volatilidad  0.249465  0.377224  0.265601  0.429276  0.323167  0.197936
# Clusters     0.000000  1.000000  2.000000  3.000000  4.000000  5.000000

# %%
cluster_output=cluster_output.drop(['Clusters'],axis=0)
cluster_output
# Out:
#                     0         1         2         3         4         5
# Retorno     -0.047236 -0.276846  0.242937  0.225708  0.007011  0.137145
# Volatilidad  0.249465  0.377224  0.265601  0.429276  0.323167  0.197936

# %%
cluster_output=cluster_output.T
cluster_output
# Out:
#     Retorno  Volatilidad
# 0 -0.047236     0.249465
# 1 -0.276846     0.377224
# 2  0.242937     0.265601
# 3  0.225708     0.429276
# 4  0.007011     0.323167
# 5  0.137145     0.197936

# %%
cluster_output[['Retorno','Volatilidad']].plot.bar(rot=0, figsize=(18,5));

# %%
stocks_moderado = cluster2.index.values
stocks_moderado
# Out:
# array(['ADBE', 'AAP', 'AES', 'A', 'AKAM', 'GOOGL', 'GOOG', 'AMZN', 'ADI',
#        'ANSS', 'AAPL', 'AZO', 'BLL', 'BA', 'BSX', 'BR', 'CDNS', 'KMX',
#        'CDW', 'CE', 'CHTR', 'CHD', 'CTAS', 'CSCO', 'COO', 'CPRT', 'CSX',
#        'DG', 'EW', 'EL', 'EXPE', 'FAST', 'FISV', 'FLT', 'FLIR', 'FTNT',
#        'GRMN', 'IT', 'GPN', 'GWW', 'HAS', 'HCA', 'IDXX', 'INTU', 'ISRG',
#        'IQV', 'JEC', 'KSU', 'KEYS', 'KLAC', 'LHX', 'LW', 'LOW', 'MKTX',
#        'MLM', 'MA', 'MKC', 'MSFT', 'MCO', 'MSI', 'MSCI', 'NKE', 'NSC',
#        'NOC', 'NRG', 'ORLY', 'PYPL', 'PGR', 'RMD', 'ROST', 'CRM', 'SPGI',
#        'SBUX', 'SNPS', 'TGT', 'TFX', 'TXN', 'TMO', 'TJX', 'TSCO', 'TDG',
#        'UNP', 'UAL', 'UHS', 'VFC', 'VRSN', 'V', 'WCG', 'ZTS'],
#       dtype=object)

# %%
stocks_conservador = cluster5.index.values
stocks_conservador
# Out:
# array(['ABT', 'ACN', 'AFL', 'APD', 'ARE', 'ALLE', 'LNT', 'ALL', 'AEE',
#        'AEP', 'AXP', 'AMT', 'AWK', 'AME', 'AMGN', 'APH', 'AON', 'AIV',
#        'ADM', 'AJG', 'AIZ', 'ATO', 'ADP', 'AVB', 'BAX', 'BBT', 'BDX',
#        'BXP', 'CBRE', 'CNP', 'CB', 'CINF', 'CTXS', 'CME', 'CMS', 'KO',
#        'CMCSA', 'ED', 'COST', 'CCI', 'DHR', 'DRI', 'DLR', 'D', 'DOV',
#        'DTE', 'DUK', 'DRE', 'ECL', 'ETR', 'EFX', 'EQIX', 'EQR', 'ESS',
#        'EVRG', 'ES', 'RE', 'EXC', 'EXPD', 'EXR', 'FRT', 'FIS', 'FE',
#        'FRC', 'GPC', 'GL', 'HIG', 'HCP', 'HSIC', 'HSY', 'HLT', 'HOLX',
#        'HD', 'HON', 'HRL', 'IEX', 'INFO', 'IR', 'ICE', 'JKHY', 'JCI',
#        'JPM', 'KMB', 'KIM', 'KMI', 'LDOS', 'LLY', 'LIN', 'LMT', 'L',
#        'MMC', 'MCD', 'MDT', 'MRK', 'MAA', 'MDLZ', 'NDAQ', 'NEE', 'NI',
#        'OKE', 'ORCL', 'PAYX', 'PEP', 'PFE', 'PNW', 'PPL', 'PG', 'PLD',
#        'PEG', 'PSA', 'DGX', 'RTN', 'O', 'REG', 'RSG', 'ROL', 'ROP',
#        'SBAC', 'SRE', 'SHW', 'SO', 'SYK', 'SYY', 'TMUS', 'TRV', 'UDR',
#        'USB', 'UTX', 'VTR', 'VRSK', 'VZ', 'WMT', 'DIS', 'WM', 'WEC',
#        'WELL', 'WU', 'WLTW', 'XEL', 'XYL', 'YUM', 'ZBH'], dtype=object)

# %%
stocks_agresivo = cluster3.index.values
stocks_agresivo
# Out:
# array(['ABMD', 'AMD', 'ALGN', 'ANET', 'ADSK', 'CMG', 'HES', 'ILMN',
#        'LRCX', 'MU', 'NFLX', 'NVDA', 'QRVO', 'STX', 'SYMC', 'TTWO',
#        'TWTR', 'TRIP', 'ULTA', 'UAA', 'UA', 'XLNX'], dtype=object)

# %%
import copy
stocks_agresivos_df = copy.deepcopy(stock)

# %%
drop_lista1 = [i for i in stocks_agresivos_df.columns if i not in stocks_agresivo]

stocks_agresivos_df=stocks_agresivos_df[stocks_agresivo]

# %%
stocks_agresivos_df['Valor_1_stock_de_cada'] = stocks_agresivos_df.sum(axis=1)
stocks_agresivos_df
# Out:
#                   ABMD        AMD        ALGN        ANET        ADSK  \
# Date
# 2018-01-02  192.490005  10.980000  224.619995  231.029999  107.120003
# 2018-01-03  195.820007  11.550000  231.199997  235.600006  109.379997
# 2018-01-04  199.250000  12.120000  233.300003  232.690002  112.070000
# 2018-01-05  202.320007  11.880000  241.070007  236.770004  110.839996
# 2018-01-08  207.800003  12.280000  248.899994  251.059998  111.419998
# ...                ...        ...         ...         ...         ...
# 2019-10-07  164.429993  28.930000  184.509995  230.940002  147.559998
# 2019-10-08  159.490005  28.230000  184.300003  229.100006  145.649994
# 2019-10-09  159.309998  28.459999  189.210007  230.029999  148.369995
# 2019-10-10  162.339996  28.379999  194.169998  227.720001  144.729996
# 2019-10-11  169.639999  29.750000  200.160004  236.440002  150.320007
#
#                    CMG        HES        ILMN        LRCX         MU  ...  \
# Date                                                                  ...
# 2018-01-02  292.950012  47.849998  224.029999  189.279999  43.669998  ...
# 2018-01-03  309.000000  49.400002  230.320007  192.500000  44.980000  ...
# 2018-01-04  307.109985  50.590000  232.990005  193.380005  46.880001  ...
# 2018-01-05  313.790009  52.160000  228.169998  196.399994  45.799999  ...
# 2018-01-08  318.470001  52.490002  227.059998  197.880005  45.549999  ...
# ...                ...        ...         ...         ...        ...  ...
# 2019-10-07  814.159973  62.700001  301.630005  232.139999  44.160000  ...
# 2019-10-08  805.880005  62.119999  288.359985  227.699997  42.639999  ...
